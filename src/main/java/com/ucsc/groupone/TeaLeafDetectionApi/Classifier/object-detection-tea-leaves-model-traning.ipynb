# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········

# %%
import os
import sys
import tensorflow as tf

# %%
# %cd /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/object_detection
# Out:
# /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/object_detection

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/object_detection'

# %%
# %cd ..
# %cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research
# /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models'

# %%
# !apt-get install -y -qq protobuf-compiler python-pil python-lxml

# %%
# %cd research
# Out:
# /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# %cd ~
# %cd /content
# %cd drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model
# Out:
# /root
# /content
# /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/:/content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/slim/'
os.environ['PYTHONPATH'] += ':/content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/:/content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/object_detection/'
# !python models/research/object_detection/builders/model_builder_test.py
 
# Change the directory path
 
# %cd models/research/object_detection
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.6.8: /usr/bin/python3
# ...

# %%
# os.chdir('object_detection')

# %%
# !cd .. && pwd && export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim/

# %%
# %cd ..

# %%
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# %%
# %pwd

# %%
# def del_all_flags(FLAGS):
#     flags_dict = FLAGS._flags()    
#     keys_list = [keys for keys in flags_dict]    
#     for keys in keys_list:
#         FLAGS.__delattr__(keys)

# del_all_flags(tf.flags.FLAGS)

# %%
# !python legacy/train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_resnet101_coco.config  --image_dir=images/
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# ...

# %%
# !python export_inference_graph.py \
    --input_type image_tensor \
    --pipeline_config_path training/faster_rcnn_resnet101_coco.config \
    --trained_checkpoint_prefix training/model.ckpt-870 \
    --output_directory tea_leaves_graph
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/tea-leaves-object-detection-model/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0907 04:49:26.277570 139654324594560 deprecation_wrapper.py:119] From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
